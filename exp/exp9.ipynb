# %% [markdown]
# # 目的

# %%
EXP_NAME = "e009_add_text_vec"

# %%
import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import root_mean_squared_error

import lightgbm as lgb

import seaborn as sns

# %%
pl.__version__
# Out:
# '1.17.1'

# %%
lgb.__version__
# Out:
# '4.5.0'

# %%
train = pd.read_csv("../data/train.csv") 
test = pd.read_csv("../data/test.csv")
monster = pd.read_csv("../data/monster.csv")
sample_submission = pd.read_csv("../data/sample_submission.csv")

# %%
monster_vec = pd.read_csv("../output/monster_vec.csv")

# %%
monster = pd.concat([monster, monster_vec], axis=1)

# %%
test
# Out:
#                    Team1               Team2
# 0        shu421 & YuYagi          kami & T88
# 1        shu421 & YuYagi       kami & RYUSHI
# 2        shu421 & YuYagi      kami & tattaka
# 3        shu421 & YuYagi      Kohecchi & T88
# 4        shu421 & YuYagi   Kohecchi & RYUSHI
# ...                  ...                 ...
# 6163      chumajin & NSK  Kinosuke & tattaka
# 6164      chumajin & NSK      K.T. & tattaka
# 6165     Kinosuke & K.T.       tattaka & NSK
# 6166  Kinosuke & tattaka          K.T. & NSK
# 6167      Kinosuke & NSK      K.T. & tattaka
#
# [6168 rows x 2 columns]

# %%
train.head(100).to_csv("train_head_100.csv", index=False)

# %% [markdown]
# # 特徴量生成

# %%
train["Team1_1_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[0])
train["Team1_2_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[1])

train["Team2_1_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[0])
train["Team2_2_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[1])

test["Team1_1_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[0])
test["Team1_2_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[1])

test["Team2_1_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[0])
test["Team2_2_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[1])

# %%
train = (
    train.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
test = (
    test.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
train.columns
# Out:
# Index(['Team1', 'Team2', 'Team1_win_ratio', 'battle1_winner', 'battle1_log',
#        'battle2_winner', 'battle2_log', 'battle3_winner', 'battle3_log',
#        'battle4_winner',
#        ...
#        'vec_374_2_2', 'vec_375_2_2', 'vec_376_2_2', 'vec_377_2_2',
#        'vec_378_2_2', 'vec_379_2_2', 'vec_380_2_2', 'vec_381_2_2',
#        'vec_382_2_2', 'vec_383_2_2'],
#       dtype='object', length=1663)

# %%
# def sorted_team_1_member(row):
#     value = "__".join(sorted([row["Team1_1_member"], row["Team1_2_member"]]))
#     return value

# def sorted_team_2_member(row):
#     value = "__".join(sorted([row["Team2_1_member"], row["Team2_2_member"]]))
#     return value

# train["sorted_team_1_member"] = train.apply(lambda x :sorted_team_1_member(x), axis=1)
# train["sorted_team_2_member"] = train.apply(lambda x :sorted_team_2_member(x), axis=1)

# test["sorted_team_1_member"] = test.apply(lambda x :sorted_team_1_member(x), axis=1)
# test["sorted_team_2_member"] = test.apply(lambda x :sorted_team_2_member(x), axis=1)

# %%
train = pl.from_pandas(train)
test = pl.from_pandas(test)

# %%
train.columns
# Out:
# ['Team1',
#  'Team2',
#  'Team1_win_ratio',
#  'battle1_winner',
#  'battle1_log',
#  'battle2_winner',
#  'battle2_log',
#  'battle3_winner',
#  'battle3_log',
#  'battle4_winner',
#  'battle4_log',
#  'battle5_winner',
#  'battle5_log',
#  'battle6_winner',
#  'battle6_log',
#  'battle7_winner',
#  'battle7_log',
#  'battle8_winner',
#  'battle8_log',
#  'battle9_winner',
#  'battle9_log',
#  'battle10_winner',
#  'battle10_log',
#  'Team1_1_member',
#  'Team1_2_member',
#  'Team2_1_member',
#  'Team2_2_member',
#  'monster_name_1_1',
#  'description_1_1',
#  'monster_type_1_1',
#  'attack_1_1',
#  'defense_1_1',
#  'speed_1_1',
#  'hp_1_1',
#  'skill1_name_1_1',
#  'skill1_power_1_1',
#  'skill1_hitrate_1_1',
#  'skill1_attribute_1_1',
#  'skill1_attack_type_1_1',
#  'skill1_status_effect_chance_1_1',
#  'skill2_name_1_1',
#  'skill2_power_1_1',
#  'skill2_hitrate_1_1',
#  'skill2_attribute_1_1',
#  'skill2_attack_type_1_1',
#  'skill2_status_effect_chance_1_1',
#  'skill3_name_1_1',
#  'skill3_power_1_1',
#  'skill3_hitrate_1_1',
#  'skill3_attribute_1_1',
#  'skill3_attack_type_1_1',
#  'skill3_status_effect_chance_1_1',
#  'vec_0_1_1',
#  'vec_1_1_1',
#  'vec_2_1_1',
#  'vec_3_1_1',
#  'vec_4_1_1',
#  'vec_5_1_1',
#  'vec_6_1_1',
#  'vec_7_1_1',
#  'vec_8_1_1',
#  'vec_9_1_1',
#  'vec_10_1_1',
#  'vec_11_1_1',
#  'vec_12_1_1',
#  'vec_13_1_1',
#  'vec_14_1_1',
#  'vec_15_1_1',
#  'vec_16_1_1',
#  'vec_17_1_1',
#  'vec_18_1_1',
#  'vec_19_1_1',
#  'vec_20_1_1',
#  'vec_21_1_1',
#  'vec_22_1_1',
#  'vec_23_1_1',
#  'vec_24_1_1',
#  'vec_25_1_1',
#  'vec_26_1_1',
#  'vec_27_1_1',
#  'vec_28_1_1',
#  'vec_29_1_1',
#  'vec_30_1_1',
#  'vec_31_1_1',
#  'vec_32_1_1',
#  'vec_33_1_1',
#  'vec_34_1_1',
#  'vec_35_1_1',
#  'vec_36_1_1',
#  'vec_37_1_1',
#  'vec_38_1_1',
#  'vec_39_1_1',
#  'vec_40_1_1',
#  'vec_41_1_1',
#  'vec_42_1_1',
#  'vec_43_1_1',
#  'vec_44_1_1',
#  'vec_45_1_1',
#  'vec_46_1_1',
#  'vec_47_1_1',
#  'vec_48_1_1',
#  'vec_49_1_1',
#  'vec_50_1_1',
#  'vec_51_1_1',
#  'vec_52_1_1',
#  'vec_53_1_1',
#  'vec_54_1_1',
#  'vec_55_1_1',
#  'vec_56_1_1',
#  'vec_57_1_1',
#  'vec_58_1_1',
#  'vec_59_1_1',
#  'vec_60_1_1',
#  'vec_61_1_1',
#  'vec_62_1_1',
#  'vec_63_1_1',
#  'vec_64_1_1',
#  'vec_65_1_1',
#  'vec_66_1_1',
#  'vec_67_1_1',
#  'vec_68_1_1',
#  'vec_69_1_1',
#  'vec_70_1_1',
#  'vec_71_1_1',
#  'vec_72_1_1',
#  'vec_73_1_1',
#  'vec_74_1_1',
#  'vec_75_1_1',
#  'vec_76_1_1',
#  'vec_77_1_1',
#  'vec_78_1_1',
#  'vec_79_1_1',
#  'vec_80_1_1',
#  'vec_81_1_1',
#  'vec_82_1_1',
#  'vec_83_1_1',
#  'vec_84_1_1',
#  'vec_85_1_1',
#  'vec_86_1_1',
#  'vec_87_1_1',
#  'vec_88_1_1',
#  'vec_89_1_1',
#  'vec_90_1_1',
#  'vec_91_1_1',
#  'vec_92_1_1',
#  'vec_93_1_1',
#  'vec_94_1_1',
#  'vec_95_1_1',
#  'vec_96_1_1',
#  'vec_97_1_1',
#  'vec_98_1_1',
#  'vec_99_1_1',
#  'vec_100_1_1',
#  'vec_101_1_1',
#  'vec_102_1_1',
#  'vec_103_1_1',
#  'vec_104_1_1',
#  'vec_105_1_1',
#  'vec_106_1_1',
#  'vec_107_1_1',
#  'vec_108_1_1',
#  'vec_109_1_1',
#  'vec_110_1_1',
#  'vec_111_1_1',
#  'vec_112_1_1',
#  'vec_113_1_1',
#  'vec_114_1_1',
#  'vec_115_1_1',
#  'vec_116_1_1',
#  'vec_117_1_1',
#  'vec_118_1_1',
#  'vec_119_1_1',
#  'vec_120_1_1',
#  'vec_121_1_1',
#  'vec_122_1_1',
#  'vec_123_1_1',
#  'vec_124_1_1',
#  'vec_125_1_1',
#  'vec_126_1_1',
#  'vec_127_1_1',
#  'vec_128_1_1',
#  'vec_129_1_1',
#  'vec_130_1_1',
#  'vec_131_1_1',
#  'vec_132_1_1',
#  'vec_133_1_1',
#  'vec_134_1_1',
#  'vec_135_1_1',
#  'vec_136_1_1',
#  'vec_137_1_1',
#  'vec_138_1_1',
#  'vec_139_1_1',
#  'vec_140_1_1',
#  'vec_141_1_1',
#  'vec_142_1_1',
#  'vec_143_1_1',
#  'vec_144_1_1',
#  'vec_145_1_1',
#  'vec_146_1_1',
#  'vec_147_1_1',
#  'vec_148_1_1',
#  'vec_149_1_1',
#  'vec_150_1_1',
#  'vec_151_1_1',
#  'vec_152_1_1',
#  'vec_153_1_1',
#  'vec_154_1_1',
#  'vec_155_1_1',
#  'vec_156_1_1',
#  'vec_157_1_1',
#  'vec_158_1_1',
#  'vec_159_1_1',
#  'vec_160_1_1',
#  'vec_161_1_1',
#  'vec_162_1_1',
#  'vec_163_1_1',
#  'vec_164_1_1',
#  'vec_165_1_1',
#  'vec_166_1_1',
#  'vec_167_1_1',
#  'vec_168_1_1',
#  'vec_169_1_1',
#  'vec_170_1_1',
#  'vec_171_1_1',
#  'vec_172_1_1',
#  'vec_173_1_1',
#  'vec_174_1_1',
#  'vec_175_1_1',
#  'vec_176_1_1',
#  'vec_177_1_1',
#  'vec_178_1_1',
#  'vec_179_1_1',
#  'vec_180_1_1',
#  'vec_181_1_1',
#  'vec_182_1_1',
#  'vec_183_1_1',
#  'vec_184_1_1',
#  'vec_185_1_1',
#  'vec_186_1_1',
#  'vec_187_1_1',
#  'vec_188_1_1',
#  'vec_189_1_1',
#  'vec_190_1_1',
#  'vec_191_1_1',
#  'vec_192_1_1',
#  'vec_193_1_1',
#  'vec_194_1_1',
#  'vec_195_1_1',
#  'vec_196_1_1',
#  'vec_197_1_1',
#  'vec_198_1_1',
#  'vec_199_1_1',
#  'vec_200_1_1',
#  'vec_201_1_1',
#  'vec_202_1_1',
#  'vec_203_1_1',
#  'vec_204_1_1',
#  'vec_205_1_1',
#  'vec_206_1_1',
#  'vec_207_1_1',
#  'vec_208_1_1',
#  'vec_209_1_1',
#  'vec_210_1_1',
#  'vec_211_1_1',
#  'vec_212_1_1',
#  'vec_213_1_1',
#  'vec_214_1_1',
#  'vec_215_1_1',
#  'vec_216_1_1',
#  'vec_217_1_1',
#  'vec_218_1_1',
#  'vec_219_1_1',
#  'vec_220_1_1',
#  'vec_221_1_1',
#  'vec_222_1_1',
#  'vec_223_1_1',
#  'vec_224_1_1',
#  'vec_225_1_1',
#  'vec_226_1_1',
#  'vec_227_1_1',
#  'vec_228_1_1',
#  'vec_229_1_1',
#  'vec_230_1_1',
#  'vec_231_1_1',
#  'vec_232_1_1',
#  'vec_233_1_1',
#  'vec_234_1_1',
#  'vec_235_1_1',
#  'vec_236_1_1',
#  'vec_237_1_1',
#  'vec_238_1_1',
#  'vec_239_1_1',
#  'vec_240_1_1',
#  'vec_241_1_1',
#  'vec_242_1_1',
#  'vec_243_1_1',
#  'vec_244_1_1',
#  'vec_245_1_1',
#  'vec_246_1_1',
#  'vec_247_1_1',
#  'vec_248_1_1',
#  'vec_249_1_1',
#  'vec_250_1_1',
#  'vec_251_1_1',
#  'vec_252_1_1',
#  'vec_253_1_1',
#  'vec_254_1_1',
#  'vec_255_1_1',
#  'vec_256_1_1',
#  'vec_257_1_1',
#  'vec_258_1_1',
#  'vec_259_1_1',
#  'vec_260_1_1',
#  'vec_261_1_1',
#  'vec_262_1_1',
#  'vec_263_1_1',
#  'vec_264_1_1',
#  'vec_265_1_1',
#  'vec_266_1_1',
#  'vec_267_1_1',
#  'vec_268_1_1',
#  'vec_269_1_1',
#  'vec_270_1_1',
#  'vec_271_1_1',
#  'vec_272_1_1',
#  'vec_273_1_1',
#  'vec_274_1_1',
#  'vec_275_1_1',
#  'vec_276_1_1',
#  'vec_277_1_1',
#  'vec_278_1_1',
#  'vec_279_1_1',
#  'vec_280_1_1',
#  'vec_281_1_1',
#  'vec_282_1_1',
#  'vec_283_1_1',
#  'vec_284_1_1',
#  'vec_285_1_1',
#  'vec_286_1_1',
#  'vec_287_1_1',
#  'vec_288_1_1',
#  'vec_289_1_1',
#  'vec_290_1_1',
#  'vec_291_1_1',
#  'vec_292_1_1',
#  'vec_293_1_1',
#  'vec_294_1_1',
#  'vec_295_1_1',
#  'vec_296_1_1',
#  'vec_297_1_1',
#  'vec_298_1_1',
#  'vec_299_1_1',
#  'vec_300_1_1',
#  'vec_301_1_1',
#  'vec_302_1_1',
#  'vec_303_1_1',
#  'vec_304_1_1',
#  'vec_305_1_1',
#  'vec_306_1_1',
#  'vec_307_1_1',
#  'vec_308_1_1',
#  'vec_309_1_1',
#  'vec_310_1_1',
#  'vec_311_1_1',
#  'vec_312_1_1',
#  'vec_313_1_1',
#  'vec_314_1_1',
#  'vec_315_1_1',
#  'vec_316_1_1',
#  'vec_317_1_1',
#  'vec_318_1_1',
#  'vec_319_1_1',
#  'vec_320_1_1',
#  'vec_321_1_1',
#  'vec_322_1_1',
#  'vec_323_1_1',
#  'vec_324_1_1',
#  'vec_325_1_1',
#  'vec_326_1_1',
#  'vec_327_1_1',
#  'vec_328_1_1',
#  'vec_329_1_1',
#  'vec_330_1_1',
#  'vec_331_1_1',
#  'vec_332_1_1',
#  'vec_333_1_1',
#  'vec_334_1_1',
#  'vec_335_1_1',
#  'vec_336_1_1',
#  'vec_337_1_1',
#  'vec_338_1_1',
#  'vec_339_1_1',
#  'vec_340_1_1',
#  'vec_341_1_1',
#  'vec_342_1_1',
#  'vec_343_1_1',
#  'vec_344_1_1',
#  'vec_345_1_1',
#  'vec_346_1_1',
#  'vec_347_1_1',
#  'vec_348_1_1',
#  'vec_349_1_1',
#  'vec_350_1_1',
#  'vec_351_1_1',
#  'vec_352_1_1',
#  'vec_353_1_1',
#  'vec_354_1_1',
#  'vec_355_1_1',
#  'vec_356_1_1',
#  'vec_357_1_1',
#  'vec_358_1_1',
#  'vec_359_1_1',
#  'vec_360_1_1',
#  'vec_361_1_1',
#  'vec_362_1_1',
#  'vec_363_1_1',
#  'vec_364_1_1',
#  'vec_365_1_1',
#  'vec_366_1_1',
#  'vec_367_1_1',
#  'vec_368_1_1',
#  'vec_369_1_1',
#  'vec_370_1_1',
#  'vec_371_1_1',
#  'vec_372_1_1',
#  'vec_373_1_1',
#  'vec_374_1_1',
#  'vec_375_1_1',
#  'vec_376_1_1',
#  'vec_377_1_1',
#  'vec_378_1_1',
#  'vec_379_1_1',
#  'vec_380_1_1',
#  'vec_381_1_1',
#  'vec_382_1_1',
#  'vec_383_1_1',
#  'monster_name_1_2',
#  'description_1_2',
#  'monster_type_1_2',
#  'attack_1_2',
#  'defense_1_2',
#  'speed_1_2',
#  'hp_1_2',
#  'skill1_name_1_2',
#  'skill1_power_1_2',
#  'skill1_hitrate_1_2',
#  'skill1_attribute_1_2',
#  'skill1_attack_type_1_2',
#  'skill1_status_effect_chance_1_2',
#  'skill2_name_1_2',
#  'skill2_power_1_2',
#  'skill2_hitrate_1_2',
#  'skill2_attribute_1_2',
#  'skill2_attack_type_1_2',
#  'skill2_status_effect_chance_1_2',
#  'skill3_name_1_2',
#  'skill3_power_1_2',
#  'skill3_hitrate_1_2',
#  'skill3_attribute_1_2',
#  'skill3_attack_type_1_2',
#  'skill3_status_effect_chance_1_2',
#  'vec_0_1_2',
#  'vec_1_1_2',
#  'vec_2_1_2',
#  'vec_3_1_2',
#  'vec_4_1_2',
#  'vec_5_1_2',
#  'vec_6_1_2',
#  'vec_7_1_2',
#  'vec_8_1_2',
#  'vec_9_1_2',
#  'vec_10_1_2',
#  'vec_11_1_2',
#  'vec_12_1_2',
#  'vec_13_1_2',
#  'vec_14_1_2',
#  'vec_15_1_2',
#  'vec_16_1_2',
#  'vec_17_1_2',
#  'vec_18_1_2',
#  'vec_19_1_2',
#  'vec_20_1_2',
#  'vec_21_1_2',
#  'vec_22_1_2',
#  'vec_23_1_2',
#  'vec_24_1_2',
#  'vec_25_1_2',
#  'vec_26_1_2',
#  'vec_27_1_2',
#  'vec_28_1_2',
#  'vec_29_1_2',
#  'vec_30_1_2',
#  'vec_31_1_2',
#  'vec_32_1_2',
#  'vec_33_1_2',
#  'vec_34_1_2',
#  'vec_35_1_2',
#  'vec_36_1_2',
#  'vec_37_1_2',
#  'vec_38_1_2',
#  'vec_39_1_2',
#  'vec_40_1_2',
#  'vec_41_1_2',
#  'vec_42_1_2',
#  'vec_43_1_2',
#  'vec_44_1_2',
#  'vec_45_1_2',
#  'vec_46_1_2',
#  'vec_47_1_2',
#  'vec_48_1_2',
#  'vec_49_1_2',
#  'vec_50_1_2',
#  'vec_51_1_2',
#  'vec_52_1_2',
#  'vec_53_1_2',
#  'vec_54_1_2',
#  'vec_55_1_2',
#  'vec_56_1_2',
#  'vec_57_1_2',
#  'vec_58_1_2',
#  'vec_59_1_2',
#  'vec_60_1_2',
#  'vec_61_1_2',
#  'vec_62_1_2',
#  'vec_63_1_2',
#  'vec_64_1_2',
#  'vec_65_1_2',
#  'vec_66_1_2',
#  'vec_67_1_2',
#  'vec_68_1_2',
#  'vec_69_1_2',
#  'vec_70_1_2',
#  'vec_71_1_2',
#  'vec_72_1_2',
#  'vec_73_1_2',
#  'vec_74_1_2',
#  'vec_75_1_2',
#  'vec_76_1_2',
#  'vec_77_1_2',
#  'vec_78_1_2',
#  'vec_79_1_2',
#  'vec_80_1_2',
#  'vec_81_1_2',
#  'vec_82_1_2',
#  'vec_83_1_2',
#  'vec_84_1_2',
#  'vec_85_1_2',
#  'vec_86_1_2',
#  'vec_87_1_2',
#  'vec_88_1_2',
#  'vec_89_1_2',
#  'vec_90_1_2',
#  'vec_91_1_2',
#  'vec_92_1_2',
#  'vec_93_1_2',
#  'vec_94_1_2',
#  'vec_95_1_2',
#  'vec_96_1_2',
#  'vec_97_1_2',
#  'vec_98_1_2',
#  'vec_99_1_2',
#  'vec_100_1_2',
#  'vec_101_1_2',
#  'vec_102_1_2',
#  'vec_103_1_2',
#  'vec_104_1_2',
#  'vec_105_1_2',
#  'vec_106_1_2',
#  'vec_107_1_2',
#  'vec_108_1_2',
#  'vec_109_1_2',
#  'vec_110_1_2',
#  'vec_111_1_2',
#  'vec_112_1_2',
#  'vec_113_1_2',
#  'vec_114_1_2',
#  'vec_115_1_2',
#  'vec_116_1_2',
#  'vec_117_1_2',
#  'vec_118_1_2',
#  'vec_119_1_2',
#  'vec_120_1_2',
#  'vec_121_1_2',
#  'vec_122_1_2',
#  'vec_123_1_2',
#  'vec_124_1_2',
#  'vec_125_1_2',
#  'vec_126_1_2',
#  'vec_127_1_2',
#  'vec_128_1_2',
#  'vec_129_1_2',
#  'vec_130_1_2',
#  'vec_131_1_2',
#  'vec_132_1_2',
#  'vec_133_1_2',
#  'vec_134_1_2',
#  'vec_135_1_2',
#  'vec_136_1_2',
#  'vec_137_1_2',
#  'vec_138_1_2',
#  'vec_139_1_2',
#  'vec_140_1_2',
#  'vec_141_1_2',
#  'vec_142_1_2',
#  'vec_143_1_2',
#  'vec_144_1_2',
#  'vec_145_1_2',
#  'vec_146_1_2',
#  'vec_147_1_2',
#  'vec_148_1_2',
#  'vec_149_1_2',
#  'vec_150_1_2',
#  'vec_151_1_2',
#  'vec_152_1_2',
#  'vec_153_1_2',
#  'vec_154_1_2',
#  'vec_155_1_2',
#  'vec_156_1_2',
#  'vec_157_1_2',
#  'vec_158_1_2',
#  'vec_159_1_2',
#  'vec_160_1_2',
#  'vec_161_1_2',
#  'vec_162_1_2',
#  'vec_163_1_2',
#  'vec_164_1_2',
#  'vec_165_1_2',
#  'vec_166_1_2',
#  'vec_167_1_2',
#  'vec_168_1_2',
#  'vec_169_1_2',
#  'vec_170_1_2',
#  'vec_171_1_2',
#  'vec_172_1_2',
#  'vec_173_1_2',
#  'vec_174_1_2',
#  'vec_175_1_2',
#  'vec_176_1_2',
#  'vec_177_1_2',
#  'vec_178_1_2',
#  'vec_179_1_2',
#  'vec_180_1_2',
#  'vec_181_1_2',
#  'vec_182_1_2',
#  'vec_183_1_2',
#  'vec_184_1_2',
#  'vec_185_1_2',
#  'vec_186_1_2',
#  'vec_187_1_2',
#  'vec_188_1_2',
#  'vec_189_1_2',
#  'vec_190_1_2',
#  'vec_191_1_2',
#  'vec_192_1_2',
#  'vec_193_1_2',
#  'vec_194_1_2',
#  'vec_195_1_2',
#  'vec_196_1_2',
#  'vec_197_1_2',
#  'vec_198_1_2',
#  'vec_199_1_2',
#  'vec_200_1_2',
#  'vec_201_1_2',
#  'vec_202_1_2',
#  'vec_203_1_2',
#  'vec_204_1_2',
#  'vec_205_1_2',
#  'vec_206_1_2',
#  'vec_207_1_2',
#  'vec_208_1_2',
#  'vec_209_1_2',
#  'vec_210_1_2',
#  'vec_211_1_2',
#  'vec_212_1_2',
#  'vec_213_1_2',
#  'vec_214_1_2',
#  'vec_215_1_2',
#  'vec_216_1_2',
#  'vec_217_1_2',
#  'vec_218_1_2',
#  'vec_219_1_2',
#  'vec_220_1_2',
#  'vec_221_1_2',
#  'vec_222_1_2',
#  'vec_223_1_2',
#  'vec_224_1_2',
#  'vec_225_1_2',
#  'vec_226_1_2',
#  'vec_227_1_2',
#  'vec_228_1_2',
#  'vec_229_1_2',
#  'vec_230_1_2',
#  'vec_231_1_2',
#  'vec_232_1_2',
#  'vec_233_1_2',
#  'vec_234_1_2',
#  'vec_235_1_2',
#  'vec_236_1_2',
#  'vec_237_1_2',
#  'vec_238_1_2',
#  'vec_239_1_2',
#  'vec_240_1_2',
#  'vec_241_1_2',
#  'vec_242_1_2',
#  'vec_243_1_2',
#  'vec_244_1_2',
#  'vec_245_1_2',
#  'vec_246_1_2',
#  'vec_247_1_2',
#  'vec_248_1_2',
#  'vec_249_1_2',
#  'vec_250_1_2',
#  'vec_251_1_2',
#  'vec_252_1_2',
#  'vec_253_1_2',
#  'vec_254_1_2',
#  'vec_255_1_2',
#  'vec_256_1_2',
#  'vec_257_1_2',
#  'vec_258_1_2',
#  'vec_259_1_2',
#  'vec_260_1_2',
#  'vec_261_1_2',
#  'vec_262_1_2',
#  'vec_263_1_2',
#  'vec_264_1_2',
#  'vec_265_1_2',
#  'vec_266_1_2',
#  'vec_267_1_2',
#  'vec_268_1_2',
#  'vec_269_1_2',
#  'vec_270_1_2',
#  'vec_271_1_2',
#  'vec_272_1_2',
#  'vec_273_1_2',
#  'vec_274_1_2',
#  'vec_275_1_2',
#  'vec_276_1_2',
#  'vec_277_1_2',
#  'vec_278_1_2',
#  'vec_279_1_2',
#  'vec_280_1_2',
#  'vec_281_1_2',
#  'vec_282_1_2',
#  'vec_283_1_2',
#  'vec_284_1_2',
#  'vec_285_1_2',
#  'vec_286_1_2',
#  'vec_287_1_2',
#  'vec_288_1_2',
#  'vec_289_1_2',
#  'vec_290_1_2',
#  'vec_291_1_2',
#  'vec_292_1_2',
#  'vec_293_1_2',
#  'vec_294_1_2',
#  'vec_295_1_2',
#  'vec_296_1_2',
#  'vec_297_1_2',
#  'vec_298_1_2',
#  'vec_299_1_2',
#  'vec_300_1_2',
#  'vec_301_1_2',
#  'vec_302_1_2',
#  'vec_303_1_2',
#  'vec_304_1_2',
#  'vec_305_1_2',
#  'vec_306_1_2',
#  'vec_307_1_2',
#  'vec_308_1_2',
#  'vec_309_1_2',
#  'vec_310_1_2',
#  'vec_311_1_2',
#  'vec_312_1_2',
#  'vec_313_1_2',
#  'vec_314_1_2',
#  'vec_315_1_2',
#  'vec_316_1_2',
#  'vec_317_1_2',
#  'vec_318_1_2',
#  'vec_319_1_2',
#  'vec_320_1_2',
#  'vec_321_1_2',
#  'vec_322_1_2',
#  'vec_323_1_2',
#  'vec_324_1_2',
#  'vec_325_1_2',
#  'vec_326_1_2',
#  'vec_327_1_2',
#  'vec_328_1_2',
#  'vec_329_1_2',
#  'vec_330_1_2',
#  'vec_331_1_2',
#  'vec_332_1_2',
#  'vec_333_1_2',
#  'vec_334_1_2',
#  'vec_335_1_2',
#  'vec_336_1_2',
#  'vec_337_1_2',
#  'vec_338_1_2',
#  'vec_339_1_2',
#  'vec_340_1_2',
#  'vec_341_1_2',
#  'vec_342_1_2',
#  'vec_343_1_2',
#  'vec_344_1_2',
#  'vec_345_1_2',
#  'vec_346_1_2',
#  'vec_347_1_2',
#  'vec_348_1_2',
#  'vec_349_1_2',
#  'vec_350_1_2',
#  'vec_351_1_2',
#  'vec_352_1_2',
#  'vec_353_1_2',
#  'vec_354_1_2',
#  'vec_355_1_2',
#  'vec_356_1_2',
#  'vec_357_1_2',
#  'vec_358_1_2',
#  'vec_359_1_2',
#  'vec_360_1_2',
#  'vec_361_1_2',
#  'vec_362_1_2',
#  'vec_363_1_2',
#  'vec_364_1_2',
#  'vec_365_1_2',
#  'vec_366_1_2',
#  'vec_367_1_2',
#  'vec_368_1_2',
#  'vec_369_1_2',
#  'vec_370_1_2',
#  'vec_371_1_2',
#  'vec_372_1_2',
#  'vec_373_1_2',
#  'vec_374_1_2',
#  'vec_375_1_2',
#  'vec_376_1_2',
#  'vec_377_1_2',
#  'vec_378_1_2',
#  'vec_379_1_2',
#  'vec_380_1_2',
#  'vec_381_1_2',
#  'vec_382_1_2',
#  'vec_383_1_2',
#  'monster_name_2_1',
#  'description_2_1',
#  'monster_type_2_1',
#  'attack_2_1',
#  'defense_2_1',
#  'speed_2_1',
#  'hp_2_1',
#  'skill1_name_2_1',
#  'skill1_power_2_1',
#  'skill1_hitrate_2_1',
#  'skill1_attribute_2_1',
#  'skill1_attack_type_2_1',
#  'skill1_status_effect_chance_2_1',
#  'skill2_name_2_1',
#  'skill2_power_2_1',
#  'skill2_hitrate_2_1',
#  'skill2_attribute_2_1',
#  'skill2_attack_type_2_1',
#  'skill2_status_effect_chance_2_1',
#  'skill3_name_2_1',
#  'skill3_power_2_1',
#  'skill3_hitrate_2_1',
#  'skill3_attribute_2_1',
#  'skill3_attack_type_2_1',
#  'skill3_status_effect_chance_2_1',
#  'vec_0_2_1',
#  'vec_1_2_1',
#  'vec_2_2_1',
#  'vec_3_2_1',
#  'vec_4_2_1',
#  'vec_5_2_1',
#  'vec_6_2_1',
#  'vec_7_2_1',
#  'vec_8_2_1',
#  'vec_9_2_1',
#  'vec_10_2_1',
#  'vec_11_2_1',
#  'vec_12_2_1',
#  'vec_13_2_1',
#  'vec_14_2_1',
#  'vec_15_2_1',
#  'vec_16_2_1',
#  'vec_17_2_1',
#  'vec_18_2_1',
#  'vec_19_2_1',
#  'vec_20_2_1',
#  'vec_21_2_1',
#  'vec_22_2_1',
#  'vec_23_2_1',
#  'vec_24_2_1',
#  'vec_25_2_1',
#  'vec_26_2_1',
#  'vec_27_2_1',
#  'vec_28_2_1',
#  'vec_29_2_1',
#  'vec_30_2_1',
#  'vec_31_2_1',
#  'vec_32_2_1',
#  'vec_33_2_1',
#  'vec_34_2_1',
#  'vec_35_2_1',
#  'vec_36_2_1',
#  'vec_37_2_1',
#  'vec_38_2_1',
#  'vec_39_2_1',
#  'vec_40_2_1',
#  'vec_41_2_1',
#  'vec_42_2_1',
#  'vec_43_2_1',
#  'vec_44_2_1',
#  'vec_45_2_1',
#  'vec_46_2_1',
#  'vec_47_2_1',
#  'vec_48_2_1',
#  'vec_49_2_1',
#  'vec_50_2_1',
#  'vec_51_2_1',
#  'vec_52_2_1',
#  'vec_53_2_1',
#  'vec_54_2_1',
#  'vec_55_2_1',
#  'vec_56_2_1',
#  'vec_57_2_1',
#  'vec_58_2_1',
#  'vec_59_2_1',
#  'vec_60_2_1',
#  'vec_61_2_1',
#  'vec_62_2_1',
#  'vec_63_2_1',
#  'vec_64_2_1',
#  'vec_65_2_1',
#  'vec_66_2_1',
#  'vec_67_2_1',
#  'vec_68_2_1',
#  'vec_69_2_1',
#  'vec_70_2_1',
#  'vec_71_2_1',
#  'vec_72_2_1',
#  'vec_73_2_1',
#  'vec_74_2_1',
#  'vec_75_2_1',
#  'vec_76_2_1',
#  'vec_77_2_1',
#  'vec_78_2_1',
#  'vec_79_2_1',
#  'vec_80_2_1',
#  'vec_81_2_1',
#  'vec_82_2_1',
#  'vec_83_2_1',
#  'vec_84_2_1',
#  'vec_85_2_1',
#  'vec_86_2_1',
#  'vec_87_2_1',
#  'vec_88_2_1',
#  'vec_89_2_1',
#  'vec_90_2_1',
#  'vec_91_2_1',
#  'vec_92_2_1',
#  'vec_93_2_1',
#  'vec_94_2_1',
#  'vec_95_2_1',
#  'vec_96_2_1',
#  'vec_97_2_1',
#  'vec_98_2_1',
#  'vec_99_2_1',
#  'vec_100_2_1',
#  'vec_101_2_1',
#  'vec_102_2_1',
#  'vec_103_2_1',
#  'vec_104_2_1',
#  'vec_105_2_1',
#  'vec_106_2_1',
#  'vec_107_2_1',
#  'vec_108_2_1',
#  'vec_109_2_1',
#  'vec_110_2_1',
#  'vec_111_2_1',
#  'vec_112_2_1',
#  'vec_113_2_1',
#  'vec_114_2_1',
#  'vec_115_2_1',
#  'vec_116_2_1',
#  'vec_117_2_1',
#  'vec_118_2_1',
#  'vec_119_2_1',
#  'vec_120_2_1',
#  'vec_121_2_1',
#  'vec_122_2_1',
#  'vec_123_2_1',
#  'vec_124_2_1',
#  'vec_125_2_1',
#  'vec_126_2_1',
#  'vec_127_2_1',
#  'vec_128_2_1',
#  'vec_129_2_1',
#  ...]

# %%
USE_COL = ["Team1_1_member", "Team1_2_member", "Team2_1_member", "Team2_2_member"]
USE_COL += [col + "_1_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_1_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
# USE_COL += ["sorted_team_1_member", "sorted_team_2_member"]

CATEGORICAL_FEATURE = [
    "Team1_1_member",
    "Team1_2_member",
    "Team2_1_member",
    "Team2_2_member",
    "monster_type_1_1",
    "monster_type_1_2",
    "monster_type_2_1",
    "monster_type_2_2",
    "skill1_attribute_1_1",
    "skill1_attribute_1_2",
    "skill1_attribute_2_1",
    "skill1_attribute_2_2",
    "skill2_attribute_1_1",
    "skill2_attribute_1_2",
    "skill2_attribute_2_1",
    "skill2_attribute_2_2",
    "skill3_attribute_1_1",
    "skill3_attribute_1_2",
    "skill3_attribute_2_1",
    "skill3_attribute_2_2",
    "skill1_name_1_1",
    "skill1_name_1_2",
    "skill1_name_2_1",
    "skill1_name_2_2",
    "skill1_attack_type_1_1",
    "skill1_attack_type_1_2",
    "skill1_attack_type_2_1",
    "skill1_attack_type_2_2",
    "skill2_name_1_1",
    "skill2_name_1_2",
    "skill2_name_2_1",
    "skill2_name_2_2",
    "skill2_attack_type_1_1",
    "skill2_attack_type_1_2",
    "skill2_attack_type_2_1",
    "skill2_attack_type_2_2",
    "skill3_name_1_1",
    "skill3_name_1_2",
    "skill3_name_2_1",
    "skill3_name_2_2",
    "skill3_attack_type_1_1",
    "skill3_attack_type_1_2",
    "skill3_attack_type_2_1",
    "skill3_attack_type_2_2",
    # "sorted_team_1_member",
    # "sorted_team_2_member"
]
TARGET_COL = "Team1_win_ratio"
FOLD_NUM = 5
SEED = 42

# %%
# Categorical型への変換
train = train.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))
test = test.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))

# %%
# Foldの作成
fold_arr = np.zeros(train.height)
fold = KFold(n_splits=FOLD_NUM, shuffle=True, random_state=SEED)

for idx, (_, val_idx) in enumerate(fold.split(train)):
    fold_arr[val_idx] = idx

train = train.with_columns(pl.Series(fold_arr).cast(pl.Int64).alias("fold"))

# %%
# LightGBMで用いるパラメータを指定
params = {
    "objective": "regression",
    "metric": "rmse",
    "max_depth": -1,
    "min_data_in_leaf": 10,  # 1つの葉に入る最小のデータ数
    "num_leaves": 24,  # 2**max_depthより少し小さめにすると過学習を防げる
    "learning_rate": 0.01,  # 1回のiterationで学習を進める割合、大きいと学習が早く終わる。小さいと学習は長いが高精度になりやすい。
    "bagging_freq": 5,  # 指定した回数ごとにbaggingを行う
    "feature_fraction": 0.9,  # 1回のiterationで利用する特徴量(列方向)の割合
    "bagging_fraction": 0.8,  # 1回のiterationで利用するデータ(行方向)の割合
    "verbose": -1,  # 出力するログレベルの変更、-1はFatalなログのみを出力
    "seed": SEED,  # ランダムシードの固定
    "lambda_l1": 0.4,  # 正則化のためのパラメータ
    "lambda_l2": 0.4,  # 正則化のためのパラメータ
}

# %%
# テストデータに対する推論、特徴量重要度(後述)を計算するために、モデルを保存するobjectを作成
models = []

# Cross Validationによる学習の実施
for fold in range(FOLD_NUM):
    print(f"Start fold {fold}")

    # foldごとにtrainとvalidに分ける
    train_fold = train.filter(pl.col("fold") != fold)
    valid_fold = train.filter(pl.col("fold") == fold)

    # X(説明変数)とy(目的変数)に分ける
    X_train = train_fold.select(USE_COL)
    X_valid = valid_fold.select(USE_COL)
    y_train = train_fold.select(TARGET_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # LightGBMが認識可能な形にデータセットを変換
    lgb_train = lgb.Dataset(X_train.to_pandas(), y_train.to_pandas())
    lgb_eval = lgb.Dataset(
        X_valid.to_pandas(), y_valid.to_pandas(), reference=lgb_train
    )

    # モデルの学習
    model = lgb.train(
        params,
        lgb_train,
        num_boost_round=10000,  # 学習のiteration回数
        valid_sets=[lgb_train, lgb_eval],
        callbacks=[
            lgb.early_stopping(
                stopping_rounds=100
            ),  # Early stopingの回数、binary_loglossが改善しないiterationが100回続いたら学習を止める
            lgb.log_evaluation(100),  # 指定したiteration回数ごとにlogを出力する
        ],
    )

    # モデルを保存
    models.append([fold, model])
# Out:
# Start fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.196915	valid_1's rmse: 0.20476
# [200]	training's rmse: 0.15867	valid_1's rmse: 0.173207
# [300]	training's rmse: 0.14185	valid_1's rmse: 0.160487
# [400]	training's rmse: 0.13341	valid_1's rmse: 0.154616
# [500]	training's rmse: 0.128336	valid_1's rmse: 0.152032
# [600]	training's rmse: 0.12461	valid_1's rmse: 0.150576
# [700]	training's rmse: 0.12174	valid_1's rmse: 0.149899
# [800]	training's rmse: 0.119431	valid_1's rmse: 0.149519
# [900]	training's rmse: 0.117362	valid_1's rmse: 0.149654
# Early stopping, best iteration is:
# [820]	training's rmse: 0.119004	valid_1's rmse: 0.149485
# Start fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.198239	valid_1's rmse: 0.200334
# [200]	training's rmse: 0.159796	valid_1's rmse: 0.168595
# [300]	training's rmse: 0.143194	valid_1's rmse: 0.156083
# [400]	training's rmse: 0.134418	valid_1's rmse: 0.150691
# [500]	training's rmse: 0.129028	valid_1's rmse: 0.148112
# [600]	training's rmse: 0.125487	valid_1's rmse: 0.147059
# [700]	training's rmse: 0.122505	valid_1's rmse: 0.146454
# [800]	training's rmse: 0.120218	valid_1's rmse: 0.146288
# [900]	training's rmse: 0.118127	valid_1's rmse: 0.146273
# [1000]	training's rmse: 0.116115	valid_1's rmse: 0.146127
# [1100]	training's rmse: 0.114234	valid_1's rmse: 0.146262
# Early stopping, best iteration is:
# [1000]	training's rmse: 0.116115	valid_1's rmse: 0.146127
# Start fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.197557	valid_1's rmse: 0.206953
# [200]	training's rmse: 0.16002	valid_1's rmse: 0.170498
# [300]	training's rmse: 0.143661	valid_1's rmse: 0.156307
# [400]	training's rmse: 0.135227	valid_1's rmse: 0.150784
# [500]	training's rmse: 0.129547	valid_1's rmse: 0.147096
# [600]	training's rmse: 0.125838	valid_1's rmse: 0.145408
# [700]	training's rmse: 0.123028	valid_1's rmse: 0.144098
# [800]	training's rmse: 0.120681	valid_1's rmse: 0.143656
# [900]	training's rmse: 0.118557	valid_1's rmse: 0.143065
# [1000]	training's rmse: 0.116603	valid_1's rmse: 0.142985
# [1100]	training's rmse: 0.114838	valid_1's rmse: 0.142901
# [1200]	training's rmse: 0.11328	valid_1's rmse: 0.142884
# Early stopping, best iteration is:
# [1105]	training's rmse: 0.114759	valid_1's rmse: 0.14285
# Start fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.197799	valid_1's rmse: 0.202635
# [200]	training's rmse: 0.159479	valid_1's rmse: 0.170587
# [300]	training's rmse: 0.143302	valid_1's rmse: 0.159194
# [400]	training's rmse: 0.134197	valid_1's rmse: 0.153659
# [500]	training's rmse: 0.128781	valid_1's rmse: 0.151016
# [600]	training's rmse: 0.124846	valid_1's rmse: 0.149237
# [700]	training's rmse: 0.122052	valid_1's rmse: 0.148688
# [800]	training's rmse: 0.119704	valid_1's rmse: 0.148303
# [900]	training's rmse: 0.117646	valid_1's rmse: 0.147969
# [1000]	training's rmse: 0.115721	valid_1's rmse: 0.147782
# [1100]	training's rmse: 0.113981	valid_1's rmse: 0.147568
# [1200]	training's rmse: 0.112351	valid_1's rmse: 0.147573
# Early stopping, best iteration is:
# [1170]	training's rmse: 0.112787	valid_1's rmse: 0.147546
# Start fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.197784	valid_1's rmse: 0.20168
# [200]	training's rmse: 0.159251	valid_1's rmse: 0.167459
# [300]	training's rmse: 0.143209	valid_1's rmse: 0.154293
# [400]	training's rmse: 0.13504	valid_1's rmse: 0.148396
# [500]	training's rmse: 0.129719	valid_1's rmse: 0.145257
# [600]	training's rmse: 0.126203	valid_1's rmse: 0.143743
# [700]	training's rmse: 0.123287	valid_1's rmse: 0.142717
# [800]	training's rmse: 0.120792	valid_1's rmse: 0.141951
# [900]	training's rmse: 0.118726	valid_1's rmse: 0.141629
# [1000]	training's rmse: 0.116922	valid_1's rmse: 0.141451
# [1100]	training's rmse: 0.11511	valid_1's rmse: 0.141293
# [1200]	training's rmse: 0.113444	valid_1's rmse: 0.141331
# [1300]	training's rmse: 0.111876	valid_1's rmse: 0.141314
# Early stopping, best iteration is:
# [1260]	training's rmse: 0.112522	valid_1's rmse: 0.14127

# %%
# 学習データ全体に対する推論結果を保存するobjectを作成
oof = np.zeros((len(train)))

# foldの値と学習済みモデルを利用し、モデルの評価を行う
for fold, model in models:
    valid_fold = train.filter(pl.col("fold") == fold)

    X_valid = valid_fold.select(USE_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # validデータに対する推論
    y_valid_pred = model.predict(
        X_valid.to_pandas(), num_iteration=model.best_iteration
    )

    score = root_mean_squared_error(y_valid, y_valid_pred)
    print(f"fold {fold} Score: {score}")

    is_valid = train.get_column("fold") == fold
    oof[is_valid] = y_valid_pred
# Out:
# fold 0 Score: 0.14948476765714225
# fold 1 Score: 0.14612683892714273
# fold 2 Score: 0.14284961249891043
# fold 3 Score: 0.14754638687333416
# fold 4 Score: 0.1412701112636825

# %%
oof_score = root_mean_squared_error(train.get_column(TARGET_COL), oof)
oof_score
# Out:
# 0.1454867287578263

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importances = [
    model.feature_importance(importance_type="gain") for _, model in models
]
feature_importances_df = pd.DataFrame(feature_importances, columns=USE_COL)

order = feature_importances_df.mean().sort_values(ascending=False).index.tolist()
plt.figure(figsize=(10, 30))
sns.boxplot(data=feature_importances_df, orient="h", order=order)
# Out:
# <Axes: >

# %%
pred = np.array([model.predict(test[USE_COL].to_pandas()) for _, model in models])
pred = np.mean(pred, axis=0)
pred
# Out:
# array([0.77256122, 0.74947974, 0.83983994, ..., 0.36902326, 0.18287867,
#        0.73449349])

# %%
len(pred)
# Out:
# 6168

# %%
sample_submission["Team1_win_ratio"] = pred
sample_submission.to_csv(f"../submission/{EXP_NAME}_CV{oof_score:.4f}.csv", index=False)

# %%
sample_submission

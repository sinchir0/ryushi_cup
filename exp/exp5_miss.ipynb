# %% [markdown]
# # 目的

# %%
EXP_NAME = "e004_org"

# %%
import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import root_mean_squared_error

import lightgbm as lgb

import seaborn as sns

# %%
pl.__version__
# Out:
# '1.17.1'

# %%
lgb.__version__
# Out:
# '4.5.0'

# %%
train = pd.read_csv("../data/train.csv") 
test = pd.read_csv("../data/test.csv")
monster = pd.read_csv("../data/monster.csv")
sample_submission = pd.read_csv("../data/sample_submission.csv")

# %%
test
# Out:
#                    Team1               Team2
# 0        shu421 & YuYagi          kami & T88
# 1        shu421 & YuYagi       kami & RYUSHI
# 2        shu421 & YuYagi      kami & tattaka
# 3        shu421 & YuYagi      Kohecchi & T88
# 4        shu421 & YuYagi   Kohecchi & RYUSHI
# ...                  ...                 ...
# 6163      chumajin & NSK  Kinosuke & tattaka
# 6164      chumajin & NSK      K.T. & tattaka
# 6165     Kinosuke & K.T.       tattaka & NSK
# 6166  Kinosuke & tattaka          K.T. & NSK
# 6167      Kinosuke & NSK      K.T. & tattaka
#
# [6168 rows x 2 columns]

# %%
train.head(100).to_csv("train_head_100.csv", index=False)

# %% [markdown]
# # 特徴量生成

# %%
train["Team1_1_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[0])
train["Team1_2_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[1])

train["Team2_1_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[0])
train["Team2_2_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[1])

test["Team1_1_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[0])
test["Team1_2_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[1])

test["Team2_1_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[0])
test["Team2_2_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[1])

# %%
train = (
    train.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
test = (
    test.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
train.columns
# Out:
# Index(['Team1', 'Team2', 'Team1_win_ratio', 'battle1_winner', 'battle1_log',
#        'battle2_winner', 'battle2_log', 'battle3_winner', 'battle3_log',
#        'battle4_winner',
#        ...
#        'skill2_hitrate_2_2', 'skill2_attribute_2_2', 'skill2_attack_type_2_2',
#        'skill2_status_effect_chance_2_2', 'skill3_name_2_2',
#        'skill3_power_2_2', 'skill3_hitrate_2_2', 'skill3_attribute_2_2',
#        'skill3_attack_type_2_2', 'skill3_status_effect_chance_2_2'],
#       dtype='object', length=127)

# %%
# def sorted_team_1_member(row):
#     value = "__".join(sorted([row["Team1_1_member"], row["Team1_2_member"]]))
#     return value

# def sorted_team_2_member(row):
#     value = "__".join(sorted([row["Team2_1_member"], row["Team2_2_member"]]))
#     return value

# train["sorted_team_1_member"] = train.apply(lambda x :sorted_team_1_member(x), axis=1)
# train["sorted_team_2_member"] = train.apply(lambda x :sorted_team_2_member(x), axis=1)

# test["sorted_team_1_member"] = test.apply(lambda x :sorted_team_1_member(x), axis=1)
# test["sorted_team_2_member"] = test.apply(lambda x :sorted_team_2_member(x), axis=1)

# %%
train = pl.from_pandas(train)
test = pl.from_pandas(test)

# %%
USE_COL = ["Team1_1_member", "Team1_2_member", "Team2_1_member", "Team2_2_member"]
USE_COL += [col + "_1_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_1_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += ["sorted_team_1_member", "sorted_team_2_member"]

CATEGORICAL_FEATURE = [
    "Team1_1_member",
    "Team1_2_member",
    "Team2_1_member",
    "Team2_2_member",
    "monster_type_1_1",
    "monster_type_1_2",
    "monster_type_2_1",
    "monster_type_2_2",
    "skill1_attribute_1_1",
    "skill1_attribute_1_2",
    "skill1_attribute_2_1",
    "skill1_attribute_2_2",
    "skill2_attribute_1_1",
    "skill2_attribute_1_2",
    "skill2_attribute_2_1",
    "skill2_attribute_2_2",
    "skill3_attribute_1_1",
    "skill3_attribute_1_2",
    "skill3_attribute_2_1",
    "skill3_attribute_2_2",
    "skill1_name_1_1",
    "skill1_name_1_2",
    "skill1_name_2_1",
    "skill1_name_2_2",
    "skill1_attack_type_1_1",
    "skill1_attack_type_1_2",
    "skill1_attack_type_2_1",
    "skill1_attack_type_2_2",
    "skill2_name_1_1",
    "skill2_name_1_2",
    "skill2_name_2_1",
    "skill2_name_2_2",
    "skill2_attack_type_1_1",
    "skill2_attack_type_1_2",
    "skill2_attack_type_2_1",
    "skill2_attack_type_2_2",
    "skill3_name_1_1",
    "skill3_name_1_2",
    "skill3_name_2_1",
    "skill3_name_2_2",
    "skill3_attack_type_1_1",
    "skill3_attack_type_1_2",
    "skill3_attack_type_2_1",
    "skill3_attack_type_2_2",
    # "sorted_team_1_member",
    # "sorted_team_2_member"
]
TARGET_COL = "Team1_win_ratio"
FOLD_NUM = 5
SEED = 42

# %%
# Categorical型への変換
train = train.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))
test = test.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))

# %%
# Foldの作成
fold_arr = np.zeros(train.height)
fold = KFold(n_splits=FOLD_NUM, shuffle=True, random_state=SEED)

for idx, (_, val_idx) in enumerate(fold.split(train)):
    fold_arr[val_idx] = idx

train = train.with_columns(pl.Series(fold_arr).cast(pl.Int64).alias("fold"))

# %%
# LightGBMで用いるパラメータを指定
params = {
    "objective": "regression",
    "metric": "rmse",
    "max_depth": -1,
    "min_data_in_leaf": 10,  # 1つの葉に入る最小のデータ数
    "num_leaves": 24,  # 2**max_depthより少し小さめにすると過学習を防げる
    "learning_rate": 0.01,  # 1回のiterationで学習を進める割合、大きいと学習が早く終わる。小さいと学習は長いが高精度になりやすい。
    "bagging_freq": 5,  # 指定した回数ごとにbaggingを行う
    "feature_fraction": 0.9,  # 1回のiterationで利用する特徴量(列方向)の割合
    "bagging_fraction": 0.8,  # 1回のiterationで利用するデータ(行方向)の割合
    "verbose": -1,  # 出力するログレベルの変更、-1はFatalなログのみを出力
    "seed": SEED,  # ランダムシードの固定
    "lambda_l1": 0.4,  # 正則化のためのパラメータ
    "lambda_l2": 0.4,  # 正則化のためのパラメータ
}

# %%
# テストデータに対する推論、特徴量重要度(後述)を計算するために、モデルを保存するobjectを作成
models = []

# Cross Validationによる学習の実施
for fold in range(FOLD_NUM):
    print(f"Start fold {fold}")

    # foldごとにtrainとvalidに分ける
    train_fold = train.filter(pl.col("fold") != fold)
    valid_fold = train.filter(pl.col("fold") == fold)

    # X(説明変数)とy(目的変数)に分ける
    X_train = train_fold.select(USE_COL)
    X_valid = valid_fold.select(USE_COL)
    y_train = train_fold.select(TARGET_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # LightGBMが認識可能な形にデータセットを変換
    lgb_train = lgb.Dataset(X_train.to_pandas(), y_train.to_pandas())
    lgb_eval = lgb.Dataset(
        X_valid.to_pandas(), y_valid.to_pandas(), reference=lgb_train
    )

    # モデルの学習
    model = lgb.train(
        params,
        lgb_train,
        num_boost_round=10000,  # 学習のiteration回数
        valid_sets=[lgb_train, lgb_eval],
        callbacks=[
            lgb.early_stopping(
                stopping_rounds=100
            ),  # Early stopingの回数、binary_loglossが改善しないiterationが100回続いたら学習を止める
            lgb.log_evaluation(100),  # 指定したiteration回数ごとにlogを出力する
        ],
    )

    # モデルを保存
    models.append([fold, model])
# Out:
# Start fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.193537	valid_1's rmse: 0.20633
# [200]	training's rmse: 0.156001	valid_1's rmse: 0.179508
# [300]	training's rmse: 0.140348	valid_1's rmse: 0.170125
# [400]	training's rmse: 0.131176	valid_1's rmse: 0.165809
# [500]	training's rmse: 0.124578	valid_1's rmse: 0.16363
# [600]	training's rmse: 0.118994	valid_1's rmse: 0.161705
# [700]	training's rmse: 0.114125	valid_1's rmse: 0.160903
# [800]	training's rmse: 0.109713	valid_1's rmse: 0.159933
# [900]	training's rmse: 0.105767	valid_1's rmse: 0.159303
# [1000]	training's rmse: 0.101893	valid_1's rmse: 0.158907
# [1100]	training's rmse: 0.0982827	valid_1's rmse: 0.158483
# [1200]	training's rmse: 0.0951112	valid_1's rmse: 0.157987
# [1300]	training's rmse: 0.0920239	valid_1's rmse: 0.157795
# [1400]	training's rmse: 0.0890807	valid_1's rmse: 0.157617
# [1500]	training's rmse: 0.0862196	valid_1's rmse: 0.157414
# [1600]	training's rmse: 0.0836379	valid_1's rmse: 0.157215
# [1700]	training's rmse: 0.0811864	valid_1's rmse: 0.157032
# [1800]	training's rmse: 0.0789042	valid_1's rmse: 0.156742
# [1900]	training's rmse: 0.0765307	valid_1's rmse: 0.156677
# [2000]	training's rmse: 0.0744356	valid_1's rmse: 0.156481
# [2100]	training's rmse: 0.0724077	valid_1's rmse: 0.156456
# Early stopping, best iteration is:
# [2084]	training's rmse: 0.0727353	valid_1's rmse: 0.156406
# Start fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.195364	valid_1's rmse: 0.201052
# [200]	training's rmse: 0.157355	valid_1's rmse: 0.171115
# [300]	training's rmse: 0.141173	valid_1's rmse: 0.160695
# [400]	training's rmse: 0.131841	valid_1's rmse: 0.156748
# [500]	training's rmse: 0.125123	valid_1's rmse: 0.154639
# [600]	training's rmse: 0.119457	valid_1's rmse: 0.153291
# [700]	training's rmse: 0.114673	valid_1's rmse: 0.152668
# [800]	training's rmse: 0.110347	valid_1's rmse: 0.152054
# [900]	training's rmse: 0.106525	valid_1's rmse: 0.151743
# [1000]	training's rmse: 0.102674	valid_1's rmse: 0.151496
# [1100]	training's rmse: 0.0990275	valid_1's rmse: 0.15108
# [1200]	training's rmse: 0.0957825	valid_1's rmse: 0.150914
# [1300]	training's rmse: 0.0927303	valid_1's rmse: 0.150865
# Early stopping, best iteration is:
# [1234]	training's rmse: 0.0947217	valid_1's rmse: 0.150815
# Start fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.194301	valid_1's rmse: 0.210232
# [200]	training's rmse: 0.15783	valid_1's rmse: 0.176805
# [300]	training's rmse: 0.142099	valid_1's rmse: 0.164181
# [400]	training's rmse: 0.132867	valid_1's rmse: 0.158589
# [500]	training's rmse: 0.125709	valid_1's rmse: 0.155207
# [600]	training's rmse: 0.120199	valid_1's rmse: 0.153472
# [700]	training's rmse: 0.115329	valid_1's rmse: 0.15228
# [800]	training's rmse: 0.11108	valid_1's rmse: 0.151528
# [900]	training's rmse: 0.107245	valid_1's rmse: 0.150773
# [1000]	training's rmse: 0.103551	valid_1's rmse: 0.150314
# [1100]	training's rmse: 0.0999971	valid_1's rmse: 0.149863
# [1200]	training's rmse: 0.096818	valid_1's rmse: 0.14959
# [1300]	training's rmse: 0.0937177	valid_1's rmse: 0.149624
# [1400]	training's rmse: 0.0907348	valid_1's rmse: 0.149363
# [1500]	training's rmse: 0.0878874	valid_1's rmse: 0.149126
# [1600]	training's rmse: 0.0852763	valid_1's rmse: 0.149019
# Early stopping, best iteration is:
# [1562]	training's rmse: 0.0862525	valid_1's rmse: 0.148977
# Start fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.195149	valid_1's rmse: 0.200532
# [200]	training's rmse: 0.156918	valid_1's rmse: 0.171516
# [300]	training's rmse: 0.141576	valid_1's rmse: 0.162959
# [400]	training's rmse: 0.132026	valid_1's rmse: 0.158912
# [500]	training's rmse: 0.124884	valid_1's rmse: 0.156304
# [600]	training's rmse: 0.119424	valid_1's rmse: 0.155156
# [700]	training's rmse: 0.114654	valid_1's rmse: 0.154405
# [800]	training's rmse: 0.110272	valid_1's rmse: 0.154028
# [900]	training's rmse: 0.106264	valid_1's rmse: 0.153474
# [1000]	training's rmse: 0.102504	valid_1's rmse: 0.153284
# [1100]	training's rmse: 0.0990669	valid_1's rmse: 0.152804
# [1200]	training's rmse: 0.0959406	valid_1's rmse: 0.152593
# [1300]	training's rmse: 0.092914	valid_1's rmse: 0.152414
# [1400]	training's rmse: 0.0899496	valid_1's rmse: 0.152465
# Early stopping, best iteration is:
# [1325]	training's rmse: 0.0921763	valid_1's rmse: 0.152376
# Start fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.195914	valid_1's rmse: 0.20091
# [200]	training's rmse: 0.158216	valid_1's rmse: 0.168304
# [300]	training's rmse: 0.141968	valid_1's rmse: 0.156637
# [400]	training's rmse: 0.132701	valid_1's rmse: 0.152193
# [500]	training's rmse: 0.125859	valid_1's rmse: 0.149495
# [600]	training's rmse: 0.120374	valid_1's rmse: 0.148203
# [700]	training's rmse: 0.115714	valid_1's rmse: 0.147349
# [800]	training's rmse: 0.111569	valid_1's rmse: 0.146851
# [900]	training's rmse: 0.107668	valid_1's rmse: 0.146266
# [1000]	training's rmse: 0.103911	valid_1's rmse: 0.145796
# [1100]	training's rmse: 0.100455	valid_1's rmse: 0.14558
# [1200]	training's rmse: 0.0971508	valid_1's rmse: 0.145367
# [1300]	training's rmse: 0.0939746	valid_1's rmse: 0.145117
# [1400]	training's rmse: 0.0910051	valid_1's rmse: 0.144759
# [1500]	training's rmse: 0.0881993	valid_1's rmse: 0.144666
# [1600]	training's rmse: 0.0856194	valid_1's rmse: 0.144637
# [1700]	training's rmse: 0.0830555	valid_1's rmse: 0.144449
# [1800]	training's rmse: 0.0806825	valid_1's rmse: 0.144206
# [1900]	training's rmse: 0.078362	valid_1's rmse: 0.144137
# [2000]	training's rmse: 0.0762203	valid_1's rmse: 0.144201
# Early stopping, best iteration is:
# [1905]	training's rmse: 0.078262	valid_1's rmse: 0.144129

# %%
# 学習データ全体に対する推論結果を保存するobjectを作成
oof = np.zeros((len(train)))

# foldの値と学習済みモデルを利用し、モデルの評価を行う
for fold, model in models:
    valid_fold = train.filter(pl.col("fold") == fold)

    X_valid = valid_fold.select(USE_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # validデータに対する推論
    y_valid_pred = model.predict(
        X_valid.to_pandas(), num_iteration=model.best_iteration
    )

    score = root_mean_squared_error(y_valid, y_valid_pred)
    print(f"fold {fold} Score: {score}")

    is_valid = train.get_column("fold") == fold
    oof[is_valid] = y_valid_pred
# Out:
# fold 0 Score: 0.15640575201330756
# fold 1 Score: 0.15081481381987427
# fold 2 Score: 0.1489773241477608
# fold 3 Score: 0.15237589193563553
# fold 4 Score: 0.14412860594868634

# %%
oof_score = root_mean_squared_error(train.get_column(TARGET_COL), oof)
oof_score
# Out:
# 0.15059454036351436

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importances = [
    model.feature_importance(importance_type="gain") for _, model in models
]
feature_importances_df = pd.DataFrame(feature_importances, columns=USE_COL)

order = feature_importances_df.mean().sort_values(ascending=False).index.tolist()
plt.figure(figsize=(10, 30))
sns.boxplot(data=feature_importances_df, orient="h", order=order)
# Out:
# <Axes: >

# %%
pred = np.array([model.predict(test[USE_COL].to_pandas()) for _, model in models])
pred = np.mean(pred, axis=0)
pred
# Out:
# array([0.69726255, 0.64579053, 0.73840628, ..., 0.49331203, 0.08198543,
#        0.62398481])

# %%
len(pred)
# Out:
# 6168

# %%
sample_submission["Team1_win_ratio"] = pred
sample_submission.to_csv(f"../submission/{EXP_NAME}_CV{oof_score:.4f}.csv", index=False)

# %%
sample_submission
# Out:
#       Team1_win_ratio                        Team1_Team2
# 0            0.697263         shu421 & YuYagi_kami & T88
# 1            0.645791      shu421 & YuYagi_kami & RYUSHI
# 2            0.738406     shu421 & YuYagi_kami & tattaka
# 3            0.623550     shu421 & YuYagi_Kohecchi & T88
# 4            0.560335  shu421 & YuYagi_Kohecchi & RYUSHI
# ...               ...                                ...
# 6163         0.652660  chumajin & NSK_Kinosuke & tattaka
# 6164         0.637854      chumajin & NSK_K.T. & tattaka
# 6165         0.493312      Kinosuke & K.T._tattaka & NSK
# 6166         0.081985      Kinosuke & tattaka_K.T. & NSK
# 6167         0.623985      Kinosuke & NSK_K.T. & tattaka
#
# [6168 rows x 2 columns]

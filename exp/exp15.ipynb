# %% [markdown]
# # 目的

# %%
EXP_NAME = "e015_aug_team_1_and_2"

# %%
import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import root_mean_squared_error

import lightgbm as lgb

import seaborn as sns

# %%
pl.__version__
# Out:
# '1.17.1'

# %%
lgb.__version__
# Out:
# '4.5.0'

# %%
train = pd.read_csv("../data/train.csv") 
test = pd.read_csv("../data/test.csv")
monster = pd.read_csv("../data/monster.csv")
sample_submission = pd.read_csv("../data/sample_submission.csv")

# %%
test
# Out:
#                    Team1               Team2
# 0        shu421 & YuYagi          kami & T88
# 1        shu421 & YuYagi       kami & RYUSHI
# 2        shu421 & YuYagi      kami & tattaka
# 3        shu421 & YuYagi      Kohecchi & T88
# 4        shu421 & YuYagi   Kohecchi & RYUSHI
# ...                  ...                 ...
# 6163      chumajin & NSK  Kinosuke & tattaka
# 6164      chumajin & NSK      K.T. & tattaka
# 6165     Kinosuke & K.T.       tattaka & NSK
# 6166  Kinosuke & tattaka          K.T. & NSK
# 6167      Kinosuke & NSK      K.T. & tattaka
#
# [6168 rows x 2 columns]

# %%
train.head(100).to_csv("train_head_100.csv", index=False)

# %% [markdown]
# # 特徴量生成

# %%
train["Team1_1_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[0])
train["Team1_2_member"] = train["Team1"].str.split(" & ").apply(lambda x: x[1])

train["Team2_1_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[0])
train["Team2_2_member"] = train["Team2"].str.split(" & ").apply(lambda x: x[1])

test["Team1_1_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[0])
test["Team1_2_member"] = test["Team1"].str.split(" & ").apply(lambda x: x[1])

test["Team2_1_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[0])
test["Team2_2_member"] = test["Team2"].str.split(" & ").apply(lambda x: x[1])

# %% [markdown]
# # data augmentation

# %%
train_team_aug_1 = train.copy()
train_team_aug_1["Team1_1_member"] = train["Team1_2_member"]
train_team_aug_1["Team1_2_member"] = train["Team1_1_member"]

train_team_aug_2 = train.copy()
train_team_aug_2["Team2_1_member"] = train["Team2_2_member"]
train_team_aug_2["Team2_2_member"] = train["Team2_1_member"]

# %%
train = pd.concat([train, train_team_aug_1, train_team_aug_2], axis=0).reset_index(drop=True)

# %%
train.shape
# Out:
# (10920, 27)

# %%
train = (
    train.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
test = (
    test.merge(
        monster.add_suffix("_1_1"),
        how="left",
        left_on="Team1_1_member",
        right_on="monster_name_1_1"
    ).merge(
        monster.add_suffix("_1_2"),
        how="left",
        left_on="Team1_2_member",
        right_on="monster_name_1_2"
    ).merge(
        monster.add_suffix("_2_1"),
        how="left",
        left_on="Team2_1_member",
        right_on="monster_name_2_1"
    ).merge(
        monster.add_suffix("_2_2"),
        how="left",
        left_on="Team2_2_member",
        right_on="monster_name_2_2"
    )
)

# %%
train.columns
# Out:
# Index(['Team1', 'Team2', 'Team1_win_ratio', 'battle1_winner', 'battle1_log',
#        'battle2_winner', 'battle2_log', 'battle3_winner', 'battle3_log',
#        'battle4_winner',
#        ...
#        'skill2_hitrate_2_2', 'skill2_attribute_2_2', 'skill2_attack_type_2_2',
#        'skill2_status_effect_chance_2_2', 'skill3_name_2_2',
#        'skill3_power_2_2', 'skill3_hitrate_2_2', 'skill3_attribute_2_2',
#        'skill3_attack_type_2_2', 'skill3_status_effect_chance_2_2'],
#       dtype='object', length=127)

# %%
# def sorted_team_1_member(row):
#     value = "__".join(sorted([row["Team1_1_member"], row["Team1_2_member"]]))
#     return value

# def sorted_team_2_member(row):
#     value = "__".join(sorted([row["Team2_1_member"], row["Team2_2_member"]]))
#     return value

# train["sorted_team_1_member"] = train.apply(lambda x :sorted_team_1_member(x), axis=1)
# train["sorted_team_2_member"] = train.apply(lambda x :sorted_team_2_member(x), axis=1)

# test["sorted_team_1_member"] = test.apply(lambda x :sorted_team_1_member(x), axis=1)
# test["sorted_team_2_member"] = test.apply(lambda x :sorted_team_2_member(x), axis=1)

# %%
train = pl.from_pandas(train)
test = pl.from_pandas(test)

# %%
USE_COL = ["Team1_1_member", "Team1_2_member", "Team2_1_member", "Team2_2_member"]
USE_COL += [col + "_1_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_1_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_1" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
USE_COL += [col + "_2_2" for col in monster.columns.tolist() if col not in ("description", "monster_name")]
# USE_COL += ["sorted_team_1_member", "sorted_team_2_member"]

CATEGORICAL_FEATURE = [
    "Team1_1_member",
    "Team1_2_member",
    "Team2_1_member",
    "Team2_2_member",
    "monster_type_1_1",
    "monster_type_1_2",
    "monster_type_2_1",
    "monster_type_2_2",
    "skill1_attribute_1_1",
    "skill1_attribute_1_2",
    "skill1_attribute_2_1",
    "skill1_attribute_2_2",
    "skill2_attribute_1_1",
    "skill2_attribute_1_2",
    "skill2_attribute_2_1",
    "skill2_attribute_2_2",
    "skill3_attribute_1_1",
    "skill3_attribute_1_2",
    "skill3_attribute_2_1",
    "skill3_attribute_2_2",
    "skill1_name_1_1",
    "skill1_name_1_2",
    "skill1_name_2_1",
    "skill1_name_2_2",
    "skill1_attack_type_1_1",
    "skill1_attack_type_1_2",
    "skill1_attack_type_2_1",
    "skill1_attack_type_2_2",
    "skill2_name_1_1",
    "skill2_name_1_2",
    "skill2_name_2_1",
    "skill2_name_2_2",
    "skill2_attack_type_1_1",
    "skill2_attack_type_1_2",
    "skill2_attack_type_2_1",
    "skill2_attack_type_2_2",
    "skill3_name_1_1",
    "skill3_name_1_2",
    "skill3_name_2_1",
    "skill3_name_2_2",
    "skill3_attack_type_1_1",
    "skill3_attack_type_1_2",
    "skill3_attack_type_2_1",
    "skill3_attack_type_2_2",
    # "sorted_team_1_member",
    # "sorted_team_2_member"
]
TARGET_COL = "Team1_win_ratio"
FOLD_NUM = 5
SEED = 42

# %%
# Categorical型への変換
train = train.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))
test = test.with_columns(pl.col(CATEGORICAL_FEATURE).cast(pl.Categorical))

# %%
# Foldの作成
fold_arr = np.zeros(train.height)
fold = KFold(n_splits=FOLD_NUM, shuffle=True, random_state=SEED)

for idx, (_, val_idx) in enumerate(fold.split(train)):
    fold_arr[val_idx] = idx

train = train.with_columns(pl.Series(fold_arr).cast(pl.Int64).alias("fold"))

# %%
# LightGBMで用いるパラメータを指定
params = {
    "objective": "regression",
    "metric": "rmse",
    "max_depth": -1,
    "min_data_in_leaf": 10,  # 1つの葉に入る最小のデータ数
    "num_leaves": 24,  # 2**max_depthより少し小さめにすると過学習を防げる
    "learning_rate": 0.01,  # 1回のiterationで学習を進める割合、大きいと学習が早く終わる。小さいと学習は長いが高精度になりやすい。
    "bagging_freq": 5,  # 指定した回数ごとにbaggingを行う
    "feature_fraction": 0.9,  # 1回のiterationで利用する特徴量(列方向)の割合
    "bagging_fraction": 0.8,  # 1回のiterationで利用するデータ(行方向)の割合
    "verbose": -1,  # 出力するログレベルの変更、-1はFatalなログのみを出力
    "seed": SEED,  # ランダムシードの固定
    "lambda_l1": 0.4,  # 正則化のためのパラメータ
    "lambda_l2": 0.4,  # 正則化のためのパラメータ
}

# %%
# テストデータに対する推論、特徴量重要度(後述)を計算するために、モデルを保存するobjectを作成
models = []

# Cross Validationによる学習の実施
for fold in range(FOLD_NUM):
    print(f"Start fold {fold}")

    # foldごとにtrainとvalidに分ける
    train_fold = train.filter(pl.col("fold") != fold)
    valid_fold = train.filter(pl.col("fold") == fold)

    # X(説明変数)とy(目的変数)に分ける
    X_train = train_fold.select(USE_COL)
    X_valid = valid_fold.select(USE_COL)
    y_train = train_fold.select(TARGET_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # LightGBMが認識可能な形にデータセットを変換
    lgb_train = lgb.Dataset(X_train.to_pandas(), y_train.to_pandas())
    lgb_eval = lgb.Dataset(
        X_valid.to_pandas(), y_valid.to_pandas(), reference=lgb_train
    )

    # モデルの学習
    model = lgb.train(
        params,
        lgb_train,
        num_boost_round=10000,  # 学習のiteration回数
        valid_sets=[lgb_train, lgb_eval],
        callbacks=[
            lgb.early_stopping(
                stopping_rounds=100
            ),  # Early stopingの回数、binary_loglossが改善しないiterationが100回続いたら学習を止める
            lgb.log_evaluation(100),  # 指定したiteration回数ごとにlogを出力する
        ],
    )

    # モデルを保存
    models.append([fold, model])
# Out:
# Start fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.206184	valid_1's rmse: 0.21043
# [200]	training's rmse: 0.171247	valid_1's rmse: 0.176333
# [300]	training's rmse: 0.15579	valid_1's rmse: 0.162176
# [400]	training's rmse: 0.146502	valid_1's rmse: 0.154075
# [500]	training's rmse: 0.140723	valid_1's rmse: 0.149645
# [600]	training's rmse: 0.136392	valid_1's rmse: 0.146702
# [700]	training's rmse: 0.133339	valid_1's rmse: 0.144961
# [800]	training's rmse: 0.130775	valid_1's rmse: 0.143848
# [900]	training's rmse: 0.128755	valid_1's rmse: 0.14322
# [1000]	training's rmse: 0.127001	valid_1's rmse: 0.142853
# [1100]	training's rmse: 0.125373	valid_1's rmse: 0.142555
# [1200]	training's rmse: 0.123834	valid_1's rmse: 0.142218
# [1300]	training's rmse: 0.122426	valid_1's rmse: 0.142089
# [1400]	training's rmse: 0.121124	valid_1's rmse: 0.141996
# [1500]	training's rmse: 0.12	valid_1's rmse: 0.141965
# [1600]	training's rmse: 0.118892	valid_1's rmse: 0.141916
# [1700]	training's rmse: 0.11779	valid_1's rmse: 0.141851
# Early stopping, best iteration is:
# [1675]	training's rmse: 0.118046	valid_1's rmse: 0.141822
# Start fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.206122	valid_1's rmse: 0.211469
# [200]	training's rmse: 0.171234	valid_1's rmse: 0.177969
# [300]	training's rmse: 0.155982	valid_1's rmse: 0.163503
# [400]	training's rmse: 0.146918	valid_1's rmse: 0.15517
# [500]	training's rmse: 0.140488	valid_1's rmse: 0.149794
# [600]	training's rmse: 0.13629	valid_1's rmse: 0.146831
# [700]	training's rmse: 0.133038	valid_1's rmse: 0.144909
# [800]	training's rmse: 0.130424	valid_1's rmse: 0.143588
# [900]	training's rmse: 0.128325	valid_1's rmse: 0.14278
# [1000]	training's rmse: 0.126546	valid_1's rmse: 0.142466
# [1100]	training's rmse: 0.125007	valid_1's rmse: 0.142382
# [1200]	training's rmse: 0.123576	valid_1's rmse: 0.142278
# [1300]	training's rmse: 0.122258	valid_1's rmse: 0.14214
# [1400]	training's rmse: 0.121024	valid_1's rmse: 0.142084
# [1500]	training's rmse: 0.119847	valid_1's rmse: 0.141984
# [1600]	training's rmse: 0.118725	valid_1's rmse: 0.141996
# Early stopping, best iteration is:
# [1525]	training's rmse: 0.119549	valid_1's rmse: 0.141955
# Start fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.20705	valid_1's rmse: 0.204307
# [200]	training's rmse: 0.171449	valid_1's rmse: 0.173462
# [300]	training's rmse: 0.155325	valid_1's rmse: 0.160661
# [400]	training's rmse: 0.145857	valid_1's rmse: 0.153644
# [500]	training's rmse: 0.139821	valid_1's rmse: 0.149814
# [600]	training's rmse: 0.135569	valid_1's rmse: 0.147179
# [700]	training's rmse: 0.132365	valid_1's rmse: 0.145728
# [800]	training's rmse: 0.129822	valid_1's rmse: 0.14481
# [900]	training's rmse: 0.127816	valid_1's rmse: 0.144393
# [1000]	training's rmse: 0.126061	valid_1's rmse: 0.144244
# [1100]	training's rmse: 0.124477	valid_1's rmse: 0.144025
# [1200]	training's rmse: 0.123061	valid_1's rmse: 0.144012
# [1300]	training's rmse: 0.121683	valid_1's rmse: 0.14389
# [1400]	training's rmse: 0.120422	valid_1's rmse: 0.143888
# Early stopping, best iteration is:
# [1332]	training's rmse: 0.121275	valid_1's rmse: 0.143852
# Start fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.205	valid_1's rmse: 0.212821
# [200]	training's rmse: 0.169417	valid_1's rmse: 0.180964
# [300]	training's rmse: 0.154071	valid_1's rmse: 0.167194
# [400]	training's rmse: 0.14497	valid_1's rmse: 0.159098
# [500]	training's rmse: 0.13896	valid_1's rmse: 0.154032
# [600]	training's rmse: 0.135154	valid_1's rmse: 0.151538
# [700]	training's rmse: 0.132002	valid_1's rmse: 0.149396
# [800]	training's rmse: 0.129598	valid_1's rmse: 0.148352
# [900]	training's rmse: 0.127424	valid_1's rmse: 0.147497
# [1000]	training's rmse: 0.125704	valid_1's rmse: 0.147008
# [1100]	training's rmse: 0.124168	valid_1's rmse: 0.146696
# [1200]	training's rmse: 0.122707	valid_1's rmse: 0.146449
# [1300]	training's rmse: 0.12136	valid_1's rmse: 0.146215
# [1400]	training's rmse: 0.120132	valid_1's rmse: 0.146172
# Early stopping, best iteration is:
# [1360]	training's rmse: 0.120615	valid_1's rmse: 0.146092
# Start fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.20622	valid_1's rmse: 0.20876
# [200]	training's rmse: 0.170974	valid_1's rmse: 0.176521
# [300]	training's rmse: 0.155051	valid_1's rmse: 0.16268
# [400]	training's rmse: 0.146393	valid_1's rmse: 0.155477
# [500]	training's rmse: 0.140218	valid_1's rmse: 0.15052
# [600]	training's rmse: 0.135973	valid_1's rmse: 0.14751
# [700]	training's rmse: 0.133063	valid_1's rmse: 0.145873
# [800]	training's rmse: 0.130726	valid_1's rmse: 0.144828
# [900]	training's rmse: 0.128539	valid_1's rmse: 0.143873
# [1000]	training's rmse: 0.12675	valid_1's rmse: 0.143354
# [1100]	training's rmse: 0.125165	valid_1's rmse: 0.143131
# [1200]	training's rmse: 0.123733	valid_1's rmse: 0.142926
# [1300]	training's rmse: 0.12237	valid_1's rmse: 0.142811
# [1400]	training's rmse: 0.121176	valid_1's rmse: 0.142801
# [1500]	training's rmse: 0.12002	valid_1's rmse: 0.142744
# [1600]	training's rmse: 0.118888	valid_1's rmse: 0.142685
# Early stopping, best iteration is:
# [1595]	training's rmse: 0.118941	valid_1's rmse: 0.142661

# %%
# 学習データ全体に対する推論結果を保存するobjectを作成
oof = np.zeros((len(train)))

# foldの値と学習済みモデルを利用し、モデルの評価を行う
for fold, model in models:
    valid_fold = train.filter(pl.col("fold") == fold)

    X_valid = valid_fold.select(USE_COL)
    y_valid = valid_fold.select(TARGET_COL)

    # validデータに対する推論
    y_valid_pred = model.predict(
        X_valid.to_pandas(), num_iteration=model.best_iteration
    )

    score = root_mean_squared_error(y_valid, y_valid_pred)
    print(f"fold {fold} Score: {score}")

    is_valid = train.get_column("fold") == fold
    oof[is_valid] = y_valid_pred
# Out:
# fold 0 Score: 0.14182237825282235
# fold 1 Score: 0.14195536453298124
# fold 2 Score: 0.1438521188131275
# fold 3 Score: 0.1460924564984703
# fold 4 Score: 0.14266090573116916

# %%
oof_score = root_mean_squared_error(train.get_column(TARGET_COL), oof)
oof_score
# Out:
# 0.14328536872255962

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importances = [
    model.feature_importance(importance_type="gain") for _, model in models
]
feature_importances_df = pd.DataFrame(feature_importances, columns=USE_COL)

order = feature_importances_df.mean().sort_values(ascending=False).index.tolist()
plt.figure(figsize=(10, 30))
sns.boxplot(data=feature_importances_df, orient="h", order=order)
# Out:
# <Axes: >

# %%
pred = np.array([model.predict(test[USE_COL].to_pandas()) for _, model in models])
pred = np.mean(pred, axis=0)
pred
# Out:
# array([0.76036548, 0.69200365, 0.79935336, ..., 0.31509449, 0.06464029,
#        0.65813615])

# %%
len(pred)
# Out:
# 6168

# %%
sample_submission["Team1_win_ratio"] = pred
sample_submission.to_csv(f"../submission/{EXP_NAME}_CV{oof_score:.4f}.csv", index=False)

# %%
sample_submission
# Out:
#       Team1_win_ratio                        Team1_Team2
# 0            0.760365         shu421 & YuYagi_kami & T88
# 1            0.692004      shu421 & YuYagi_kami & RYUSHI
# 2            0.799353     shu421 & YuYagi_kami & tattaka
# 3            0.526420     shu421 & YuYagi_Kohecchi & T88
# 4            0.472438  shu421 & YuYagi_Kohecchi & RYUSHI
# ...               ...                                ...
# 6163         0.848858  chumajin & NSK_Kinosuke & tattaka
# 6164         0.708047      chumajin & NSK_K.T. & tattaka
# 6165         0.315094      Kinosuke & K.T._tattaka & NSK
# 6166         0.064640      Kinosuke & tattaka_K.T. & NSK
# 6167         0.658136      Kinosuke & NSK_K.T. & tattaka
#
# [6168 rows x 2 columns]
